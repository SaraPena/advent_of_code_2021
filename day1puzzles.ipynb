# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd

# %%
inpt = pd.read_csv('day1input.csv', header=None).rename(columns = {0:'input'})
inpt
# Out:
#       input
# 0       169
# 1       150
# 2       158
# 3       163
# 4       167
# 5       151
# 6       152
# 7       153
# 8       154
# 9       159
# 10      168
# 11      176
# 12      182
# 13      183
# 14      188
# 15      182
# 16      183
# 17      184
# 18      185
# 19      195
# 20      199
# 21      198
# 22      196
# 23      211
# 24      212
# 25      202
# 26      203
# 27      208
# 28      205
# 29      204
# ...     ...
# 1970   3507
# 1971   3512
# 1972   3535
# 1973   3536
# 1974   3525
# 1975   3536
# 1976   3554
# 1977   3535
# 1978   3534
# 1979   3535
# 1980   3537
# 1981   3541
# 1982   3542
# 1983   3541
# 1984   3543
# 1985   3540
# 1986   3542
# 1987   3539
# 1988   3549
# 1989   3547
# 1990   3535
# 1991   3532
# 1992   3539
# 1993   3540
# 1994   3557
# 1995   3558
# 1996   3575
# 1997   3576
# 1998   3586
# 1999   3588
#
# [2000 rows x 1 columns]

# %%
inpt.rename(columns={0:'input'})
# Out:
#       input
# 0       169
# 1       150
# 2       158
# 3       163
# 4       167
# 5       151
# 6       152
# 7       153
# 8       154
# 9       159
# 10      168
# 11      176
# 12      182
# 13      183
# 14      188
# 15      182
# 16      183
# 17      184
# 18      185
# 19      195
# 20      199
# 21      198
# 22      196
# 23      211
# 24      212
# 25      202
# 26      203
# 27      208
# 28      205
# 29      204
# ...     ...
# 1970   3507
# 1971   3512
# 1972   3535
# 1973   3536
# 1974   3525
# 1975   3536
# 1976   3554
# 1977   3535
# 1978   3534
# 1979   3535
# 1980   3537
# 1981   3541
# 1982   3542
# 1983   3541
# 1984   3543
# 1985   3540
# 1986   3542
# 1987   3539
# 1988   3549
# 1989   3547
# 1990   3535
# 1991   3532
# 1992   3539
# 1993   3540
# 1994   3557
# 1995   3558
# 1996   3575
# 1997   3576
# 1998   3586
# 1999   3588
#
# [2000 rows x 1 columns]

# %%
len([n for n in range(len(inpt['input'])-1) if inpt['input'][n]<inpt['input'][n+1]])
# Out:
# 1226

# %%
for n in range(len(inpt)-1):
    if inpt['input'][n] < inpt['input'][n+1]:
# Out:
# 1
# 2
# 3
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# 15
# 16
# 17
# 18
# 19
# 22
# 23
# 25
# 26
# 29
# 30
# 33
# 34
# 35
# 36
# 38
# 40
# 41
# 42
# 46
# 47
# 48
# 49
# 50
# 51
# 53
# 54
# 55
# 56
# 57
# 59
# 60
# 61
# 63
# 64
# 66
# 69
# 71
# 72
# 73
# 74
# 75
# 76
# 77
# 78
# 80
# 81
# 82
# 83
# 86
# 88
# 89
# 90
# 91
# 92
# 94
# 95
# 96
# 97
# 98
# 99
# 100
# 101
# 102
# 103
# 105
# 106
# 107
# 108
# 109
# 112
# 116
# 117
# 119
# 120
# 121
# 122
# 123
# 124
# 125
# 126
# 127
# 128
# 129
# 133
# 134
# 135
# 138
# 139
# 141
# 142
# 143
# 144
# 145
# 146
# 147
# 148
# 149
# 150
# 151
# 152
# 154
# 155
# 158
# 159
# 161
# 162
# 164
# 165
# 166
# 168
# 169
# 170
# 172
# 176
# 177
# 178
# 179
# 180
# 181
# 182
# 183
# 184
# 186
# 188
# 190
# 191
# 192
# 194
# 198
# 200
# 202
# 204
# 205
# 208
# 209
# 212
# 213
# 214
# 215
# 216
# 218
# 219
# 220
# 223
# 224
# 225
# 226
# 227
# 228
# 231
# 232
# 234
# 237
# 238
# 239
# 241
# 242
# 243
# 244
# 245
# 246
# 248
# 250
# 251
# 254
# 256
# 259
# ...

# %% [markdown]
# # Part Two

# %%
set_3_list = [inpt['input'][n]+inpt['input'][n+1]+inpt['input'][n+2] for n in range(len(inpt)-2)]

# %%
len(set_3_list)
# Out:
# 1998

# %%
len([set_3_list[n] for n in range(len(set_3_list)-1) if set_3_list[n]<set_3_list[n+1]])
# Out:
# 1252
